# %% [markdown]
# # 🚀 Whisper JAX/XLA TPU Transcriber
#
# This notebook allows you to transcribe audio files using OpenAI's Whisper model, accelerated on Google Colab's TPUs with PyTorch/XLA.

# %%
# Cell 1: Install Dependencies
print("🚀 Starting Cell 1: Installing dependencies...")

import os
import subprocess

def install_dependencies():
    """Installs all required dependencies."""
    print("Uninstalling previous versions of torch and torch_xla...")
    try:
        subprocess.run("pip -q uninstall -y torch torch_xla torchvision torchaudio torchtext".split(), check=True)
    except subprocess.CalledProcessError as e:
        print(f"Error uninstalling packages: {e}")

    print("Installing PyTorch and Torch-XLA for TPU...")
    try:
        subprocess.run("pip install -q torch~=2.1.0 torch_xla[tpu]~=2.1.0 -f https://storage.googleapis.com/libtpu-releases/index.html".split(), check=True)
    except subprocess.CalledProcessError as e:
        print(f"Error installing PyTorch/XLA: {e}")

    print("Installing Hugging Face Transformers and other libraries...")
    try:
        subprocess.run("pip install -q transformers==4.38.2 sentencepiece librosa soundfile ipywidgets".split(), check=True)
    except subprocess.CalledProcessError as e:
        print(f"Error installing Hugging Face libraries: {e}")

    print("Updating apt and installing ffmpeg...")
    try:
        subprocess.run("apt-get update -qq".split(), check=True)
        subprocess.run("apt-get install -y -qq ffmpeg".split(), check=True)
    except subprocess.CalledProcessError as e:
        print(f"Error installing ffmpeg: {e}")

install_dependencies()

print("✅ Dependencies installed successfully!")

# %%
# Cell 2: Setup UI and Configuration
print("🚀 Starting Cell 2: Setting up UI and configuration...")

import ipywidgets as widgets
from IPython.display import display, HTML

# UI Enhancements
display(HTML("""
<style>
    .widget-label { min-width: 20ex !important; }
    .widget-dropdown > select { background-color: #f0f0f0; }
    .widget-text input[type="text"] { background-color: #f0f0f0; }
    .widget-button { background-color: #4CAF50 !important; color: white !important; }
</style>
"""))

# --- Widgets ---
model_selection_widget = widgets.Dropdown(
    options=[
        ("Tiny", "tiny"), 
        ("Base", "base"), 
        ("Small", "small"), 
        ("Medium", "medium"), 
        ("Large-v2", "large-v2"), 
        ("Large-v3", "large-v3")
    ],
    value="small",
    description="Whisper Model:"
)

language_selection_widget = widgets.Text(value="en", description="Language:", placeholder="e.g., en, es, fr, auto")
task_selection_widget = widgets.Dropdown(options=["transcribe", "translate"], value="transcribe", description="Task:")
precision_selection_widget = widgets.Dropdown(options=["bf16", "fp32"], value="bf16", description="Precision:")
chunk_length_widget = widgets.IntText(value=28, description="Chunk Length (s):")
stride_left_widget = widgets.IntText(value=5, description="Stride Left (s):")
stride_right_widget = widgets.IntText(value=5, description="Stride Right (s):")
generate_timestamps_widget = widgets.Checkbox(value=True, description="Generate Timestamps")
upload_button = widgets.Button(description="Start Transcription")
output_area = widgets.Output()

settings_box = widgets.VBox([
    model_selection_widget, language_selection_widget, task_selection_widget, precision_selection_widget,
    widgets.HTML("<b>Advanced Settings:</b>"),
    chunk_length_widget, stride_left_widget, stride_right_widget,
    generate_timestamps_widget,
    upload_button,
    output_area
])

display(settings_box)
print("✅ UI setup complete. Configure the settings above and click 'Start Transcription' to begin.")

# %%
# Cell 3: Load Model and Initialize Pipeline
print("🚀 Starting Cell 3: Loading model and initializing pipeline...")

import torch
import torch_xla.core.xla_model as xm
from transformers import WhisperProcessor, WhisperForConditionalGeneration, pipeline
import numpy as np
import time
import warnings

# Suppress warnings
warnings.filterwarnings("ignore")

def load_whisper_model():
    """Loads the Whisper model and processor."""
    model_name = f"openai/whisper-{model_selection_widget.value}"
    precision = torch.bfloat16 if precision_selection_widget.value == "bf16" else torch.float32
    
    print(f"Loading processor for {model_name}...")
    try:
        processor = WhisperProcessor.from_pretrained(model_name)
    except Exception as e:
        print(f"Error loading processor: {e}")
        return None, None
    
    print(f"Loading model {model_name} with {precision} precision...")
    try:
        model = WhisperForConditionalGeneration.from_pretrained(model_name, torch_dtype=precision)
        model.eval()
    except Exception as e:
        print(f"Error loading model: {e}")
        return None, None
    
    return model, processor

model, processor = load_whisper_model()
if model and processor:
    device = xm.xla_device()
    model.to(device)

    asr_pipeline = pipeline(
        "automatic-speech-recognition",
        model=model,
        tokenizer=processor.tokenizer,
        feature_extractor=processor.feature_extractor,
        torch_dtype=torch.bfloat16 if precision_selection_widget.value == "bf16" else torch.float32,
        device=device
    )

    print("🔥 Warming up XLA...")
    dummy_audio = np.zeros(16000 * 2, dtype=np.float32)
    with torch.no_grad():
        asr_pipeline(dummy_audio, chunk_length_s=30, stride_length_s=[5, 5])
    xm.mark_step()

    print("✅ Model loaded and pipeline initialized!")
else:
    print("❌ Model loading failed. Cannot proceed.")

# %%
# Cell 4: Transcribe Audio
from google.colab import files
import time
import os

def transcribe_audio_file(file_path):
    """Transcribes a single audio file."""
    start_time = time.time()
    with output_area:
        print(f"Transcribing {file_path}...")
    
    generate_kwargs = {"task": task_selection_widget.value}
    if language_selection_widget.value.lower() != "auto":
        generate_kwargs["language"] = language_selection_widget.value
        
    with torch.no_grad():
        output = asr_pipeline(
            file_path,
            chunk_length_s=chunk_length_widget.value,
            stride_length_s=[
                stride_left_widget.value, 
                stride_right_widget.value
            ],
            generate_kwargs=generate_kwargs,
            return_timestamps=generate_timestamps_widget.value
        )
    xm.mark_step()
    
    end_time = time.time()
    with output_area:
        print(f"Transcription finished in {end_time - start_time:.2f} seconds.")
    return output

def save_transcription_to_file(original_filename, transcription):
    """Saves the transcription to a text file."""
    base_filename, _ = os.path.splitext(original_filename)
    output_filename = f"{base_filename}_transcription.txt"
    
    with open(output_filename, "w", encoding="utf-8") as f:
        if generate_timestamps_widget.value and "chunks" in transcription:
            for chunk in transcription["chunks"]:
                start, end = chunk["timestamp"]
                f.write(f"[{start:.2f}s -> {end:.2f}s] {chunk['text']}\n")
        else:
            f.write(transcription["text"])
            
    with output_area:
        print(f"Transcription saved to {output_filename}")

def on_upload_button_clicked(b):
    with output_area:
        output_area.clear_output()
        print("🚀 Starting transcription process...")
        uploaded_files = files.upload()
        
        for filename, content in uploaded_files.items():
            print(f"\nProcessing {filename}...")
            with open(filename, 'wb') as f:
                f.write(content)
            
            try:
                transcription = transcribe_audio_file(filename)
                save_transcription_to_file(filename, transcription)
            except Exception as e:
                print(f"Error transcribing {filename}: {e}")
            finally:
                os.remove(filename)
        
        print("\n🎉 All files transcribed!")

upload_button.on_click(on_upload_button_clicked)
